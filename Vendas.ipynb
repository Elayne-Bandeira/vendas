# %% [markdown]
# <a href="https://colab.research.google.com/github/Elayne-Bandeira/vendas/blob/main/Vendas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

tabela = pd.read_excel("Vendas.xlsx")
print(tabela.info())
tabela = tabela.drop("Data", axis= 1)
tabela = tabela.dropna()
display(tabela)
print(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            57 non-null     datetime64[ns]
#  1   ID Loja         57 non-null     object
#  2   Produto         57 non-null     object
#  3   Quantidade      57 non-null     int64
#  4   Valor Unitário  57 non-null     int64
#  5   Valor Final     57 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 2.8+ KB
# None
#                        ID Loja           Produto  Quantidade  Valor Unitário  \
# 0            Iguatemi Campinas   Bermuda Estampa           1             169
# 1           Iguatemi Esplanada    Bermuda Xadrez           1             155
# 2               Norte Shopping           Bermuda           2             150
# 3            Iguatemi Campinas  Bermuda Listrado           3             163
# ...

# %%
print(type(tabela))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#quantas lojas tem? Bourbon Shopping SP, Center Shopping Uberlândia,	Iguatemi Campinas, Iguatemi Esplanada e Norte Shopping (5) ok

#qual valor final de cada loja? SP (4386), Uberlândia (2994),	Campinas(41720), Esplanada (2473) e Norte Shopping (4322) ok

#qual valor a loja com valor final mais alto e  mais baixo? Campinas (41720) e Esplanada (2473)

#qual produto mais vendido? Bermuda liso

#qual produto menos vendido? Bermuda linho

#qual produto mais saem em todas as lojas? A Bermuda liso que mais vende só é comercializa no Iguatemi Campinas

#qual o produto menos sai em todas as lojas? A Bermuda linho e estampa que são menos vendidas são comercializadas em todos as as Lojas

#Bermuda e linho custa 195
#Bermuda estampa custa 169
#Bermunda liso custa 157 reais

#Bermuda linho consegue ter um maior faturamento em cima da xadrez
#Bermuda linho mesmo sendo a que menos saí tem um faturamento melhor em relação as outras 5  bermudas
# Um exemplo bom é que a bermunda linho mesmo vendendo 5 bermudas a menos que xadrez ainda sim possui maior faturamento
#A Bermuda linha tem um retorno de faturamento bom comparada com as outras mesmo sendo a que menos sai em todas as lojas
#Iguatemi Campinas teve 264 itens vendidos e 233 foram apenas bermudas liso (quase 89% do faturamento)

# %%
for x in tabela.columns:
    display(tabela.groupby(x).sum())

display(tabela["Produto"].value_counts())
# Out:
# <ipython-input-4-5784ff51d1c1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   display(tabela.groupby(x).sum())
#                             Quantidade  Valor Unitário  Valor Final
# ID Loja
# Bourbon Shopping SP                 27            2135         4386
# Center Shopping Uberlândia          18            1479         2994
# Iguatemi Campinas                  264            2608        41720
# Iguatemi Esplanada                  14            1383         2473
# Norte Shopping                      27            1755         4322
# ...

# %%
#Avaliar as médias e tirar mais insghts

#olhar qual média de faturamento das lojas
#qual média é maior e menor: Campinas e Esplanada
#média de saída dos produtos

# %%
tabela.describe()
# Out:
#        Quantidade  Valor Unitário   Valor Final
# count   57.000000       57.000000     57.000000
# mean     6.140351      164.210526    980.614035
# std     17.577826       14.011139   2757.203926
# min      1.000000      150.000000    150.000000
# 25%      1.000000      155.000000    163.000000
# 50%      2.000000      163.000000    310.000000
# 75%      4.000000      169.000000    600.000000
# max    100.000000      195.000000  15700.000000

# %%
for x in tabela.columns:
    display(tabela.groupby(x).mean(numeric_only=True))
# Out:
#                             Quantidade  Valor Unitário  Valor Final
# ID Loja
# Bourbon Shopping SP           2.076923      164.230769   337.384615
# Center Shopping Uberlândia    2.000000      164.333333   332.666667
# Iguatemi Campinas            16.500000      163.000000  2607.500000
# Iguatemi Esplanada            1.750000      172.875000   309.125000
# Norte Shopping                2.454545      159.545455   392.909091
#                   Quantidade  Valor Unitário   Valor Final
# Produto
# Bermuda             2.555556           150.0    383.333333
# Bermuda Estampa     2.100000           169.0    354.900000
# Bermuda Linho       2.500000           195.0    487.500000
# Bermuda Liso       77.666667           157.0  12193.666667
# Bermuda Listrado    1.923077           163.0    313.461538
# Bermuda Xadrez      2.000000           155.0    310.000000
#             Valor Unitário  Valor Final
# Quantidade
# 1                  164.680      164.680
# ...

# %%
import plotly.express as px

#for coluna in tabela.columns:

grafico = px.histogram(tabela, x = "ID Loja" , color = "Quantidade")
display(grafico)

grafico = px.histogram(tabela, x = "ID Loja" , color = "Produto")
display(grafico)

grafico = px.histogram(tabela, x = "ID Loja" , color = "Valor Final")
display(grafico)

grafico = px.histogram(tabela, x = "Produto" , color = "Quantidade")
display(grafico)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
